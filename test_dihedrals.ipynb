# %%
import numpy as np

# %%
regular = np.loadtxt('./dihedrals.out')
scaled = np.loadtxt('./dihedrals_new.out')

# %%
for i,j in enumerate(scaled):
    if not (j==regular).all(1).any():
        print(i,j)

# %%
for i,j in enumerate(zip(scaled,regular)):
    if not (j[0]==j[1]).all():
        print(i,j)
        break

# %%
(regular[0]==scaled[0]).all(0)
# Out:
# True
