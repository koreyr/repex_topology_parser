# %%
import gromologist as gml

# %%
t = gml.Top('./example_topo/REST.top')
# Out:
# No working Gromacs compilation found, assuming all file dependencies are referred to locally; to change this, make the gmx executable visible in $PATH or specify gmx_dir for the Topology
# Keeping all conditional (#ifdef/#endif) sections, this might lead to issues if sections are being merged or moved around - look out for messages & check your topology afterwards!
# ['dihedraltypes', 'atomtypes']
# Merging sections [Subsection dihedraltypes with interaction type 4, Subsection dihedraltypes with interaction type 9] together
# Merging sections [Subsection atomtypes with interaction type - 1, Subsection atomtypes with interaction type - 1] together

# %%
t.solute_tempering([300,500],[0])
# Out:
# generating topology for effective temperature of 300 K...
# generating topology for effective temperature of 500 K...
